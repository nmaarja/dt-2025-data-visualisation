# %%
# !pip install pandas matplotlib numpy
# Out:
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import pandas as pd

df=pd.read_csv("homework5.csv")
print(df)
# Out:
#       Name  Age        Hobby  Hours_of_Study  Grade
# 0     Anna   20     Painting              12     90
# 1     Mark   21   Basketball               8     78
# 2    Sofia   19        Piano              14     95
# 3      Leo   22       Gaming               7     72
# 4      Mia   20      Reading              11     88
# 5   Oliver   21      Cycling              10     82
# 6     Emma   19      Dancing              15     96
# 7    Lucas   23  Photography               9     80
# 8     Nora   20       Hiking              13     91
# 9   Daniel   22        Chess              16     97
# 10   Clara   21     Swimming              12     89
# 11    Hugo   20      Cooking              10     84
# 12    Lina   19         Yoga              14     92
# 13     Max   22     Football               8     76
# 14   Julia   21     Knitting              11     87
# 15   Felix   23      Running               9     79
# 16   Elina   20      Drawing              13     90
# ...

# %% [markdown]
# 1. Who puts in the most effort?

# %%
import matplotlib.pyplot as plt
avg_hours = df.groupby("Name")["Hours_of_Study"].mean()

#bar chart
avg_hours.plot(kind="bar", x="Name", y="Hours_of_Study")

#titles
plt.title("who puts in the most effort?")
plt.ylabel("Hours studied")
plt.show()

# %% [markdown]
# Erik study the most, 17 hours. Daniel study also a lot, 16 hours.
# Mark, Max and Leo are studying the least (8, 8 and 7 hours).

# %% [markdown]
# 2. With which hobby does a student learn the most?

# %%
import matplotlib.pyplot as plt
avg_hours = df.groupby("Hobby")["Hours_of_Study"].mean().sort_values(ascending=False)

plt.figure(figsize=(8, 8))

#bar chart
avg_hours.plot(kind="pie", x="Hubby", y="Hours_of_Study", legend=False, autopct='%1.1f%%')

#titles
plt.title("With which hobby does a student learn the most?")
plt.ylabel("Hobby")
plt.show()

# %% [markdown]
# The most study the students, whos hobbies are programming and chess.
# The least study the students, whos hobbies are gaming and football.

# %% [markdown]
# 3. Does more studying = better grades?

# %%
plt.scatter(df["Hours_of_Study"], df["Grade"], s=df ["Hours_of_Study"]*30, alpha=0.6)
plt.xlabel("Hours")
plt.ylabel("Grade")
plt.title("Does more studying = better grades? (Check exeptions!)")
plt.show()

# %% [markdown]
# With this chart we see that more studying means better grade and less studying means lower grade.

# %% [markdown]
# 4. How consistent are hours of study and age?

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))
df[["Hours_of_Study", "Age"]].boxplot()
plt.title("How consistent are hours of study and age?")
plt.ylabel("Value")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Here we can see that hours of study vary a lot (7-17 hours), while age does not vary this much (19-23 years).
