# %%
number = 3 + 5;
print("The total is", +number)
# Out:
# The total is 8

# %%
name = "Maarja" # if its a string, we need to write inside the double quotes
print("Hello " +name)
# Out:
# Hello Maarja

# %%
for number in range(5):
    print(number)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for letter in name:
    print(letter)
    # "Maarja" is inside double quotes. Python automatically understand this as a string (Name).
    # strings in phyton are iteratable
# Out:
# M
# a
# a
# r
# j
# a

# %%
age = 17
if age <=7: print("free")
else: print("Buy a ticket")
if age <=18: print ("Buy a child ticket")
else: print ("Buy adult ticket")
# Out:
# Buy a ticket
# Buy a child ticket

# %%
sentence = "racecarlevelfield"

# extract first 3 letters
print("Print first 3 letters:", sentence [0:3]) #starts: ends
print (sentence [:3])

#letters from 5-9
print (sentence[4:9])

#letters from 5th to end
print (sentence [5:])

#extract the last character
print (sentence[-1])

# extract last 4 characters
print (sentence[-4:])

#extract first letter of the substring starting from 5
#sentence[5:] will extract a substring starting from 5
#[0] this will take the first character of that substring
print (sentence[5:][0])

#extract first 5 letters of the substring starting from 5
print (sentence[5:][:5])

#exract entire text
print (sentence[:])

#extract every 2nd character
print(sentence [::2])
# Out:
# Print first 3 letters: rac
# rac
# carle
# arlevelfield
# d
# ield
# a
# arlev
# racecarlevelfield
# rccreefed

# %%
sentence = "Alice went to the park and saw a beautiful bird singing"

words = sentence.split(" ") #split the sentence to words
print(words)

#extract first word
print(words[0])

# first 3 words
print (*words[0:3])

# last 3 words
print(*words[-3:])

#print number of words
print(len(words))
# Out:
# ['Alice', 'went', 'to', 'the', 'park', 'and', 'saw', 'a', 'beautiful', 'bird', 'singing']
# Alice
# Alice went to
# beautiful bird singing
# 11

# %%
pip install wordcloud # this is the library we are using work wordcloud
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 539.2/539.2 kB 18.8 MB/s eta 0:00:00
# ...
#   WARNING: The script wordcloud_cli is installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud

wc = WordCloud().generate("rain brings hope hope")

img =wc.to_image()
img.show()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
import urllib.request # this one we use to work with URLs

text = urllib.request.urlopen("https://raw.githubusercontent.com/nmaarja/dt-2025-data-visualisation/refs/heads/codespace-jubilant-orbit-gr97595599x39g76/notebooks/class_work/poem.txt").read().decode("utf-8")

text[:50]

WordCloud().generate_from_text(text).to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
WordCloud(stopwords=["and", "then", "but", "the", "to", "on"], background_color="yellow").generate_from_text(text).to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
from PIL import Image # import image class from PIL
import urllib.request # library to work with URL

img =urllib.request.urlretrieve("https://drive.google.com/uc?export=download&id=1V1Iyi9itARCcZLAx7J6747DP54D7we-A",
    "image1.png")

Image.open("image1.png")

# https://drive.google.com/file/d/1V1Iyi9itARCcZLAx7J6747DP54D7we-A/view?usp=sharing - see on faili link drivest, kust saab file id
#  "https://drive.google.com/uc?export=download&id=FILE_ID", "image1.png" - sellega saab url-i, peab file id panema
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=739x731>

# %%
from wordcloud import WordCloud
from PIL import Image # import image class from PIL
import urllib.request # library to work with URL
import numpy as np # in order to work with image masks

text = urllib.request.urlopen("https://drive.google.com/uc?export=download&id=1eSJhQo_GQwjbqJinGqKCWWh6iEG2WBvl").read().decode()
# https://drive.google.com/file/d/1eSJhQo_GQwjbqJinGqKCWWh6iEG2WBvl/view?usp=sharing 

img = urllib.request.urlretrieve("https://drive.google.com/uc?export=download&id=1V1Iyi9itARCcZLAx7J6747DP54D7we-A",
    "image1.png")

WordCloud(mask=np.array(Image.open("image1.png")),background_color="gray").generate_from_text(text).to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=739x731>
